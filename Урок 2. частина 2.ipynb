# %% [markdown]
# # Урок 2. Основи мови програмування Python
# ## Частина 2. Числа
# Числа в Python бувають різні:
#  - цілі числа(int): 122, -4,99999999, 0o177,0x9ff,ob101010
#  - дійсні числа (float): 1.0, 3.14, 5.4Е21, 4.0е21
#  - комплексні числа (complex): 3 + 4j, 3.0+ 4.0j
#  - числа з фіксованою точністю % decimal.Decimal('0.1')
#  - раціональні числа:  fractions.Fraction(3, 4)
#
#  Операції з цілими і дісними числами
#
#    x + y -  сума
#
#    x - y  - різниця
#
#    x * y  - добуток
#
#    x / y -  частка
#
#    x // y - ділення з округленням вниз ( до найближчого меншого числа)
#
#    x % y - остача від ділення
#
#    divmod(X,Y)   - пара (x // y,x % y)
#
#    -x      - унарний мінус – повертає x протилежного знаку
#
#    x **y  - x піднесене до степеня y
#
#    pow(x,y[,z])  - х в степені у,[х в степені у по  модулю z: розрахуннок остачі від ділення числа х в степені у на
#    число z(модуль) ]
#
#    X.as_integer_ratio()   - повертає пару цілих чисел, відношення якого дорівнює дійсному  Х
#
#    X.is_integer()  - перевірка - чи являється значення дійсного Х цілим числом
#
#    int([рядок-число],[основа системи числення]) - перетворення до цілого числа у десятковій системі від 2 до 36 ( за замовчцванням в десяткову)
#
#
#    bin(x)  - перетворення цілого числа в двійковий рядок
#
#    hex(x)-  перетворення цілого числа в шістнадцятковий рядок
#
#    oct(x) - перетворення цілого числа у вісімковий рядок

# %%
# Python 2 and 3 compatibility
# pip install future
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
from builtins import *

# %% [markdown]
# #### Цілі числа
# Змінні та літерали цього типу набувають значень з (обмеженої)
# множини цілих чисел. Цілий тип у Python, при необхідності, позначають
# int.

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test3.png")

# %%
print(3-2)
# Out:
# 1

# %%
print(3+2)
# Out:
# 5

# %%
print(3*2)
# Out:
# 6

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3**2)
# Out:
# 9

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test4.png")

# %% [markdown]
# Можна також використовувати дужки для управління порядком виконання операцій

# %%
standard_order = 2 + 3*4
print(standard_order)
my_order = (2 + 3)*4
print(my_order)
# Out:
# 14
# 20

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test5.png")

# %%
print(-3 ** 2)
print(3 ** -2)
# Out:
# -9
# 0.1111111111111111

# %% [markdown]
# Як бачимо у першому випадку cпочатку виконується операція
# піднесення до степеня, а вже потім застосовується унарний мінус, а в
# другому випадку навпаки.

# %% [markdown]
# Приклад.  Знайти суму цифр двозначного числа.
# Розв’язок. Нехай 𝑥 – задане двозначне число, наприклад 25. Сума цифр цього числа є сумою першої та другої цифр цього числа: 2 + 5 =7. Першу цифру цього числа можна знайти як ділення числа 𝑥 націло на 10. Друга ж цифра цього числа є остачею від ділення числа 𝑥 на 10. Тоді програма буде мати вигляд

# %%
x = int(input("Введіть двозначне число "))
first = x // 10 # first - перша цифра числа
second = x % 10 # second - друга цифра числа
suma = first + second
print("Сума цифр числа %d = %d" % (x, suma))
# Out:
# Введіть двозначне число 25
# Сума цифр числа 25 = 7

# %% [markdown]
# Зауважимо, що операція input повертає літерал рядкового типу. Тому у першому рядку програми, відбувається перетворення результату введення з клавіатури до цілого числа за допомогою інструкції int. Результатом виконання цієї програми для введеного числа 25 буде:

# %% [markdown]
# Введіть двозначне число 25

# %% [markdown]
# Сума цифр числа 25 = 7

# %% [markdown]
# #### Раціональні числа

# %%
print(.1 + .1)
# Out:
# 0.2

# %% [markdown]
# #### Цілі числа в Python 2 i Python 3
# У Python 2 результатом ділення двох чисел - також ціле число, а в Python 3 - float.

# %%
print(3/2)
# Out:
# 1.5

# %% [markdown]
# В Python 3 результат - 1.5, в Python 2 (без подключенyя future) - 1

# %% [markdown]
# ## Комплексні числа
# Комплексні числа у Python задають парою – дійсною і уявною частиною. Для позначення уявної частини, поруч з її значенням
# використовують символ j. Комплексний тип у Python, позначають complex

# %%
print("|{0}| = {1}".format (complex(2, 3), abs(complex(2, 3))))
print ("{0} * {1} = {2}".format(complex(1, 1), complex(2, 3), complex(1, 1) * complex(2, 3)))
# Out:
# |(2+3j)| = 3.605551275463989
# (1+1j) * (2+3j) = (-1+5j)

# %% [markdown]
# Вводити з клавіатури комплексні числа треба також у алгебраїчній формі використовуючи у якості уявної одиниці символ j

# %%
c = complex(input("z = "))
print (c)

# %%
Для комплексних чисел у Python визначені чотири основні арифметичні операції, а також операція унарний мінус і піднесення до
степеня

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test.png")

# %% [markdown]
# Крім цього для комплексних чисел визначені такі базові функції

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test1.png")

# %% [markdown]
# Розширений набір функцій для роботи з комплексними числами містить бібліотека cmath. Вона містить додаткові функції і сталі
# наведені у таблиці.

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test2.png")

# %% [markdown]
# ### Приклад.

# %% [markdown]
# Доведемо зв’язок між трьома магічними сталими 𝑒, 𝜋 ,𝑖: 𝑒^(𝑖*𝜋) = −1
# Розв’язок. Скористаємося бібліотекою cmath

# %%
import cmath # підключаємо модуль cmath
i = 1j # задамо уявну одиницю
pi = cmath.pi # задамо число пі
z = cmath.exp(i * pi)
print(z)
# Out:
# (-1+1.2246467991473532e-16j)

# %% [markdown]
# Результатом виконання вищенаведеної програми буде виведення на екран числа (-1+1.2246467991473532e-16j).
# У якому уявна частина майже дорівнює нулю.

# %% [markdown]
# ## Числа з фіксованою точністю та раціональні числа
# Для вирішення проблем, пов'язаних з точністю представлення простих дійсних чисел введені дійсні числа з фіксованою точністю і раціональні числа (числа, представлені дробом, тобто парою цілих чисел - чисельником і знаменником).

# %%
print(1.1/3)
from decimal import Decimal
from decimal import getcontext
getcontext().prec = 3
Decimal('4') / 3 == Decimal('1.33')
# Out:
# 0.3666666666666667
# True

# %%
from decimal import Decimal
from decimal import getcontext
getcontext().prec = 2
print(Decimal('1.10') / 3)
# Out:
# 0.37

# %%
print(7/71)
print(7/71*71 == 7)
# Out:
# 0.09859154929577464
# False

# %%
from fractions import Fraction
print(Fraction(7, 71) * 71 == 7)
# Out:
# True

# %% [markdown]
# #### Пріоритет арифметичних операцій в Python

# %%
from IPython.display import Image
Image("C:/Users/XTreme.ws/Desktop/Python/test6.png")
